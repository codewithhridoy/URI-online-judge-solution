# %% [markdown]
# <h1 style="color: green">Would you weep when I die?</h1>

# %% [markdown]
# # Question 2

# %%
lis = [23, 324, 453, 430, 12, 432, 32]

for i in range(len(lis)):
    for j in range(len(lis) - i - 1):
        if lis[j] < lis[j + 1]:
            lis[j], lis[j + 1] = lis[j + 1], lis[j]
print(lis[2])
# Out:
# 430

# %% [markdown]
# # Question 3

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/1.csv')
pd.options.display.max_columns = None
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.dtypes
# Out:
# school         object
# sex            object
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic       object
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# Gavg          float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
def encoder(df):
    for c in df.columns:
        if df[c].dtypes == 'object':
            label_encoder = LabelEncoder()
            encoded_values = label_encoder.fit_transform(df[c])
            df[c] = encoded_values
    return df

# %%
X = df.drop(['age', 'sex', 'guardian', 'address', 'famsize', 'health', 'romantic', 'goout'], axis=1)
y = X['Gavg']
X = X.drop(['Gavg'], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X = encoder(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.85)

# %%
from sklearn.linear_model import LinearRegression

# %%
X.head()
# Out:
#    school  Pstatus  Medu  Fedu  Mjob  Fjob  reason  traveltime  studytime  \
# 0       0        0     4     4     0     4       0           2          2
# 1       0        1     1     1     0     2       0           1          2
# 2       0        1     1     1     0     2       2           1          2
# 3       0        1     4     2     1     3       1           1          3
# 4       0        1     3     3     2     2       1           1          2
#
#    failures  schoolsup  famsup  paid  activities  nursery  higher  internet  \
# 0         0          1       0     0           0        1       1         0
# 1         0          0       1     0           0        0       1         1
# 2         3          1       0     1           0        1       1         1
# 3         0          0       1     1           1        1       1         1
# 4         0          0       1     1           0        1       1         0
#
#    famrel  freetime  Dalc  Walc  absences
# ...

# %%
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.19264538063764614
